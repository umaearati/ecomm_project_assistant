# %%
print("ok")
# Out:
# ok

# %%
b64="..."

# %%
b64="..."

# %%
import base64
import numpy as np

decoded = base64.b64decode(b64)
vector = np.frombuffer(decoded, dtype=np.float32)
print(vector.tolist())
# Out:
# [1.1286078489661803e+35, -5.2307376726727316e-20, -2.5435304068676084e+33, -1.106763591637478e-25, 1.099668062366126e-14, -1.0700044933774312e+22, -6.046251028045827e+25, 2148230301220864.0, -1.2398592492981724e-30, 16009.8095703125, -9.479194533936693e-27, -4.291713739570293e+32, 0.01729690469801426, 1.219266539008878e-17, 2.7286159159721984e+16, -178823053312.0, -5.776883125305176, -1802182852608.0, -1.768933624009863e-19, 2.904370273791326e+21, -8.17231129048875e-19, 5.2286003801415624e-18, 6.819331900730392e-32, -6.802109904551589e+28, -6.277361789255905e-22, -1.4080281829365049e-08, 3.231967845966338e+27, -9.312596965644147e+19, -3409487.0, 189837279232.0, -1.6031219356517643e-18, -2.456308151817863e+18, -4.70737973046198e-07, 7902164992.0, 1947239.5, 3.8381925269241277e-28, 6.336248924770349e+35, -1.2670882828911847e-31, -1.5368605910462407e-12, -1.1638412281311588e+31, 1.2869848534180256e-19, -2.7733718189060367e+31, -1.9643500589213444e-25, -0.29543858766555786, 1.65171107043
# ...

# %%
import undetected_chromedriver as uc
# Out:
# I0000 00:00:1758027810.892664  270193 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers

# %%
# GOOGLE_API_KEY="AIzaSyDCdZAWGErQTbOmCKArQG-lbzA8gTfLmMI"
GOOGLE_API_KEY="AIzaSyDEn00f5UKDLpHNlNnrMoattFL9dgUkOgE"

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import os

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")  # or just put your key as a string

# Initialize with a valid embeddings model
embeddings = GoogleGenerativeAIEmbeddings(
    api_key=GOOGLE_API_KEY,
    model="models/embedding-001"  # required
)

# Test embedding
try:
    vector = embeddings.embed_query("Hello world")
    print("Embedding successful!")
except Exception as e:
    print("Embedding failed:", e)
# Out:
# E0000 00:00:1758033148.966625  270193 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1758033148.977451  270193 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# Embedding successful!
